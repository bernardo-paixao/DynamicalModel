# %% [markdown]
# # Equations of motion
#
# $ m_{CG} \frac{d^2 \overrightarrow{S}_{CG}}{dt^2} = \overrightarrow{F}_{FRanchor}+\overrightarrow{F}_{FLanchor}+\overrightarrow{F}_{RLanchor}+\overrightarrow{F}_{RRanchor} + \overrightarrow{F}_{Faero} + \overrightarrow{F}_{Raero} + m_{CG} \overrightarrow{g}$
#
# $ \bm{I}_{CG} \frac{d^2 \overrightarrow{\theta}_{CG}}{dt^2} = \left(\overrightarrow{S}_{CG}-\overrightarrow{S}_{FRanchor} \right) \times \overrightarrow{F}_{FRanchor} + \left(\overrightarrow{S}_{CG}-\overrightarrow{S}_{FLanchor} \right) \times\overrightarrow{F}_{FLanchor} + \left(\overrightarrow{S}_{CG}-\overrightarrow{S}_{RLanchor} \right) \times\overrightarrow{F}_{RLanchor}+ \left(\overrightarrow{S}_{CG}-\overrightarrow{S}_{RRanchor} \right) \times \overrightarrow{F}_{RRanchor} + \left(\overrightarrow{S}_{CG}-\overrightarrow{S}_{Faero} \right) \times \overrightarrow{F}_{Faero} + \left( \overrightarrow{S}_{CG}-\overrightarrow{S}_{Raero} \right) \times \overrightarrow{F}_{Raero} $
#
# $ m_{FR} \frac{d^2 \overrightarrow{S}_{FR}}{dt^2} = \bm{K}_{tyre} \left( \overrightarrow{S}_{FRtrack}-\overrightarrow{S}_{FRwheel}\right) - \bm{K}_{FRspring} \left( \overrightarrow{S}_{FRwheel}-\overrightarrow{S}_{FRanchor}\right) - \bm{C}_{FRdamper} \left( \frac{d\overrightarrow{S}_{FRwheel}}{dt}-\frac{d\overrightarrow{S}\_{FRanchor}}{dt}\right) $
#
# $ ^{Geo}{\overrightarrow{S}_{FRanchor}} = ^{Geo}\bm{M}^{Car} {}^{Car}{\overrightarrow{S}_{FRanchor}}$
# $ ^{Geo}{\overrightarrow{S}_{FLanchor}} = ^{Geo}\bm{M}^{Car} {}^{Car}{\overrightarrow{S}_{FLanchor}}$
# $ ^{Geo}{\overrightarrow{S}_{RRanchor}} = ^{Geo}\bm{M}^{Car} {}^{Car}{\overrightarrow{S}_{RLanchor}}$
# $ ^{Geo}{\overrightarrow{S}_{RLanchor}} = ^{Geo}\bm{M}^{Car} {}^{Car}{\overrightarrow{S}_{RRanchor}}$

# %% [markdown]
# # Variable substitution
#
# $\frac{d^2 \overrightarrow{S}_{FRwheel}}{dt^2} = \overrightarrow{\dot{x}}_1$
#
# $\frac{d \overrightarrow{S}_{FRwheel}}{dt} = \overrightarrow{x}_1$
#
# $\overrightarrow{S}_{FRwheel} = \overrightarrow{x}_2 $
#
# $\frac{d^2 \overrightarrow{S}_{FLwheel}}{dt^2} = \overrightarrow{\dot{x}}_3$
#
# $\frac{d \overrightarrow{S}_{FLwheel}}{dt} = \overrightarrow{x}_3$
#
# $\overrightarrow{S}_{FLwheel} = \overrightarrow{x}_4 $
#
# $\frac{d^2 \overrightarrow{S}_{RRwheel}}{dt^2} = \overrightarrow{\dot{x}}_5$
#
# $\frac{d \overrightarrow{S}_{RRwheel}}{dt} = \overrightarrow{x}_5$
#
# $\overrightarrow{S}_{RRwheel} = \overrightarrow{x}_6 $
#
# $\frac{d^2 \overrightarrow{S}_{RLwheel}}{dt^2} = \overrightarrow{\dot{x}}_7$
#
# $\frac{d \overrightarrow{S}_{RLwheel}}{dt} = \overrightarrow{x}_7$
#
# $\overrightarrow{S}_{RLwheel} = \overrightarrow{x}_8 $
#
# $\frac{d^2 \overrightarrow{S}_{CG}}{dt^2} = \overrightarrow{\dot{x}}_9$
#
# $\frac{d \overrightarrow{S}_{CG}}{dt} = \overrightarrow{x}_9$
#
# $\overrightarrow{S}_{CG} = \overrightarrow{x}_{10} $
#
# $\frac{d^2 \overrightarrow{\theta}_{CG}}{dt^2} = \overrightarrow{\dot{x}}_{11}$
#
# $\frac{d \overrightarrow{\theta}_{CG}}{dt} = \overrightarrow{x}_{11}$
#
# $\overrightarrow{\theta}_{CG} = \overrightarrow{x}_{12} $
#
# $\overrightarrow{\dot{S}}_{RLanchor} = \overrightarrow{x}_{13} $
#
# $\overrightarrow{S}_{RLanchor} = \overrightarrow{x}_{14} $
#
# $\overrightarrow{\dot{S}}_{RRanchor} = \overrightarrow{x}_{15} $
#
# $\overrightarrow{S}_{RRanchor} = \overrightarrow{x}_{16} $
#
# $\overrightarrow{\dot{S}}_{FLanchor} = \overrightarrow{x}_{17} $
#
# $\overrightarrow{S}_{FLanchor} = \overrightarrow{x}_{18} $
#
# $\overrightarrow{\dot{S}}_{FRanchor} = \overrightarrow{x}_{19} $
#
# $\overrightarrow{S}_{FRanchor} = \overrightarrow{x}_{20} $

# %% [markdown]
# # Augmented ODE system
#
# ### Unsprung parts
#
# $ m_{FR} \overrightarrow{\dot{x}}_1 = \bm{K}_{tyre} \left( \overrightarrow{S}_{FRtrack}-\overrightarrow{x}_2 \right) - \bm{K}_{FRspring} \left( \overrightarrow{x}_2 - \overrightarrow{x}_{19} \right) - \bm{C}_{FRdamper} \left( \overrightarrow{x}_1 -\overrightarrow{x}_{18}\right) $
#
# $ m_{FL} \overrightarrow{\dot{x}}_3 = \bm{K}_{tyre} \left( \overrightarrow{S}_{FLtrack}-\overrightarrow{x}_4 \right) - \bm{K}_{FLspring} \left( \overrightarrow{x}_4 - \overrightarrow{x}_{17} \right) - \bm{C}_{FLdamper} \left( \overrightarrow{x}_3 -\overrightarrow{x}_{16}\right) $
#
# $ m_{RR} \overrightarrow{\dot{x}}_5 = \bm{K}_{tyre} \left( \overrightarrow{S}_{RRtrack}-\overrightarrow{x}_6 \right) - \bm{K}_{RRspring} \left( \overrightarrow{x}_6 - \overrightarrow{x}_{15} \right) - \bm{C}_{RRdamper} \left( \overrightarrow{x}_5 -\overrightarrow{x}_{14}\right) $
#
# $ m_{RL} \overrightarrow{\dot{x}}_7 = \bm{K}_{tyre} \left( \overrightarrow{S}_{RLtrack}-\overrightarrow{x}_8 \right) - \bm{K}_{RLspring} \left( \overrightarrow{x}_8 - \overrightarrow{x}_{13} \right) - \bm{C}_{RLdamper} \left( \overrightarrow{x}_7 -\overrightarrow{x}_{12}\right) $
#
# ### CG
#
# $ m_{CG} \overrightarrow{\dot{x}}_8 = \bm{K}_{FRspring} \left( \overrightarrow{x}_2 - \overrightarrow{x}_{19} \right) + \bm{C}_{FRdamper} \left( \overrightarrow{x}_1 -\overrightarrow{x}_{18}\right) + \bm{K}_{FLspring} \left( \overrightarrow{x}_4 - \overrightarrow{x}_{17} \right) + \bm{C}_{FLdamper} \left( \overrightarrow{x}_3 -\overrightarrow{x}_{16}\right) +\bm{K}_{RLspring} \left( \overrightarrow{x}_8 - \overrightarrow{x}_{13} \right) + \bm{C}_{RLdamper} \left( \overrightarrow{x}_7 -\overrightarrow{x}_{12}\right) +\bm{K}_{RRspring} \left( \overrightarrow{x}_6 - \overrightarrow{x}_{15} \right) + \bm{C}_{RRdamper} \left( \overrightarrow{x}_5 -\overrightarrow{x}_{14}\right) + \overrightarrow{F}_{Faero} + \overrightarrow{F}_{Raero} + m_{CG} \overrightarrow{g}$
#
# $ \bm{I}_{CG} \overrightarrow{\dot{x}}_{10} = \left(\overrightarrow{x}_{9}-\overrightarrow{x}_{19} \right) \times \left[ {K}_{FRspring} \left( \overrightarrow{x}_2 - \overrightarrow{x}_{19} \right) + \bm{C}_{FRdamper} \left( \overrightarrow{x}_1 -\overrightarrow{x}_{18}\right) \right] + \left(\overrightarrow{x}_{9} - \overrightarrow{x}_{17} \right) \times \left[ \bm{K}_{FLspring} \left( \overrightarrow{x}_4 - \overrightarrow{x}_{17} \right) + \bm{C}_{FLdamper} \left( \overrightarrow{x}_3 -\overrightarrow{x}_{16}\right) \right] + \left(\overrightarrow{x}_{9} - \overrightarrow{x}_{13} \right) \times \left[ \bm{K}_{RLspring} \left( \overrightarrow{x}_8 - \overrightarrow{x}_{13} \right) + \bm{C}_{RLdamper} \left( \overrightarrow{x}_7 -\overrightarrow{x}_{12}\right) \right] + \left( \overrightarrow{x}_{9} - \overrightarrow{x}_{15} \right) \times \left[ \bm{K}_{RRspring} \left( \overrightarrow{x}_6 - \overrightarrow{x}_{15} \right) + \bm{C}_{RRdamper} \left( \overrightarrow{x}_5 -\overrightarrow{x}_{14}\right) \right] $
#
# ### Kinematic
#
# $ norm(\overrightarrow{x}_{19} - \overrightarrow{x}_{17}) = $ Front axle width
#
# $ norm(\overrightarrow{x}_{15}-\overrightarrow{x}_{13}) = $ Rear axle width
#
# $ norm(\overrightarrow{x}_{15}-\overrightarrow{x}_{19}) = $ Wheel base
#
# $ norm(\overrightarrow{x}_{13}-\overrightarrow{x}_{17}) = $ Wheel base
#
# $ norm(\overrightarrow{x}_{15}-\overrightarrow{x}_{17}) = $ Diagonal distance
#
# $ norm(\overrightarrow{x}_{13}-\overrightarrow{x}_{19}) = $ Diagonal distance
